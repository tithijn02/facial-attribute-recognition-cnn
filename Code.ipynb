# %%
#installing necessary libraries
import numpy as np
import pandas as pd

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy>=1.18.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: matplotlib>=3.1.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 6)) (3.9.2)
# Requirement already satisfied: opencv-python>=4.2.0.32 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 9)) (4.11.0.86)
# Requirement already satisfied: tensorflow>=2.0.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 12)) (2.18.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 15)) (1.6.1)
# Requirement already satisfied: h5py>=2.10.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 16)) (3.12.1)
# Requirement already satisfied: imutils>=0.5.3 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 19)) (0.5.4)
# Requirement already satisfied: jupyter in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 22)) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.0.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.0.0->-r requirements.txt (line 3)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.0.0->-r requirements.txt (line 3)) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.0->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.0->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.0->-r requirements.txt (line 6)) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.0->-r requirements.txt (line 6)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.0->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.0->-r requirements.txt (line 6)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.0->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow>=2.0.0->-r requirements.txt (line 12)) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (75.8.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (1.69.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (3.8.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (0.31.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=0.22.0->-r requirements.txt (line 15)) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=0.22.0->-r requirements.txt (line 15)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=0.22.0->-r requirements.txt (line 15)) (3.5.0)
# Requirement already satisfied: notebook in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter->-r requirements.txt (line 22)) (7.3.2)
# Requirement already satisfied: jupyter-console in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter->-r requirements.txt (line 22)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter->-r requirements.txt (line 22)) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter->-r requirements.txt (line 22)) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter->-r requirements.txt (line 22)) (8.1.5)
# Requirement already satisfied: jupyterlab in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter->-r requirements.txt (line 22)) (4.3.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 22)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 22)) (1.8.9)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 22)) (8.29.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 22)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 22)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 22)) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 22)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 22)) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 22)) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 22)) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 22)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 22)) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 22)) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-console->jupyter->-r requirements.txt (line 22)) (3.0.48)
# Requirement already satisfied: pygments in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-console->jupyter->-r requirements.txt (line 22)) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 22)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 22)) (0.27.2)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 22)) (3.1.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 22)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 22)) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 22)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 22)) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbconvert->jupyter->-r requirements.txt (line 22)) (4.13.1)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 22)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbconvert->jupyter->-r requirements.txt (line 22)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbconvert->jupyter->-r requirements.txt (line 22)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbconvert->jupyter->-r requirements.txt (line 22)) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbconvert->jupyter->-r requirements.txt (line 22)) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbconvert->jupyter->-r requirements.txt (line 22)) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbconvert->jupyter->-r requirements.txt (line 22)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbconvert->jupyter->-r requirements.txt (line 22)) (1.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (0.45.1)
# Requirement already satisfied: webencodings in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 22)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 22)) (1.4.0)
# Requirement already satisfied: anyio in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (4.8.0)
# Requirement already satisfied: certifi in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (1.0.7)
# Requirement already satisfied: idna in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (3.10)
# Requirement already satisfied: sniffio in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (0.14.0)
# Requirement already satisfied: decorator in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 22)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 22)) (0.19.2)
# Requirement already satisfied: stack-data in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 22)) (0.6.3)
# Requirement already satisfied: colorama in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 22)) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 22)) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 22)) (308)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 22)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 22)) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 22)) (4.23.0)
# Requirement already satisfied: rich in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (13.9.4)
# Requirement already satisfied: namex in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (0.0.8)
# Requirement already satisfied: optree in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (0.14.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbformat>=5.7->nbconvert->jupyter->-r requirements.txt (line 22)) (2.21.1)
# Requirement already satisfied: wcwidth in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 22)) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (2.3.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (3.1.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 22)) (2.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 22)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 22)) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 22)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 22)) (0.36.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 22)) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (0.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 22)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 22)) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 22)) (0.2.3)
# Requirement already satisfied: fqdn in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (24.11.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow>=2.0.0->-r requirements.txt (line 12)) (0.1.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\dashd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 22)) (2.9.0.20241206)
# Note: you may need to restart the kernel to use updated packages.

# %%
import PIL
import matplotlib.pyplot as plt
import matplotlib.patches as patches

import tensorflow as tf

from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing import image

# %%
## Defining the path to the datasets, please change your file path accordingly to the location of the CelebA dataset
key_points_data_path = "list_landmarks_align_celeba.csv"
images_data_path = "img_align_celeba/img_align_celeba"

# Since, the dataset is very huge. Hence, we will only select 10000K images
images_data_size = 10000

# Original image dimensions
x_org = 178    # original x value
y_org = 218    # original y value

#Let's scale the images to new dimensions

# New image dimensions
x_ = 100                            # new value of x
image_size_ratio = x_org / y_org    # dimensions ratio
y_ = int(image_size_ratio * x_)     # new value of y

# Image Sizes
original_image_size = (x_org, y_org)
new_image_size = (x_,y_)

# The image size that will be used in the training process
image_size_training = new_image_size

# %% [markdown]
# ## Loading the key points data

# %%
# load the dataset (key points)
df_org = pd.read_csv(key_points_data_path)
df_org = df_org[:images_data_size]

# %% [markdown]
# ## Converting images into an array

# %%
images_data = list()
for idx in range(df_org.shape[0]):
    # Retrieving the path based upon the index
    path = "{}/{}".format(str(images_data_path),str(df_org.iloc[idx].image_id))
    
    # Reading images using PIL library
    image = PIL.Image.open(path).resize(image_size_training)
    image_array = np.asarray(image) / 255
    
    # Appending the images to a list
    images_data.append(image_array)
    
# Converting images_data to an array from list
images_data = np.array(images_data)

# %% [markdown]
# ## Plotting a sample image

# %%
# Plotting a sample image
plt.imshow(images_data[700])

# %%
print("Images Data Arrays Shape:", images_data.shape)
print("Key Points Data Shape:", df_org.shape)
# Out:
# Images Data Arrays Shape: (1000, 81, 100, 3)
# Key Points Data Shape: (1000, 11)

# %%
#check null values
df_org.isnull().sum()
# Out:
# image_id        0
# lefteye_x       0
# lefteye_y       0
# righteye_x      0
# righteye_y      0
# nose_x          0
# nose_y          0
# leftmouth_x     0
# leftmouth_y     0
# rightmouth_x    0
# rightmouth_y    0
# dtype: int64

# %%
df_org.describe()
# Out:
#          lefteye_x    lefteye_y   righteye_x   righteye_y       nose_x  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     69.263000   111.201000   107.722000   111.221000    87.774000
# std       1.740362     1.116174     1.682125     1.211456     6.758002
# min      62.000000   105.000000    96.000000   101.000000    65.000000
# 25%      68.000000   111.000000   107.000000   111.000000    84.000000
# 50%      69.000000   111.000000   108.000000   111.000000    88.000000
# 75%      70.000000   112.000000   109.000000   112.000000    91.000000
# max      82.000000   118.000000   116.000000   116.000000   120.000000
#
#             nose_y  leftmouth_x  leftmouth_y  rightmouth_x  rightmouth_y
# count  1000.000000  1000.000000  1000.000000   1000.000000   1000.000000
# mean    135.110000    71.161000   151.994000    105.717000    152.146000
# std       4.493338     3.217675     1.797553      3.344562      1.744054
# min     113.000000    61.000000   145.000000     92.000000    144.000000
# 25%     133.000000    69.000000   151.000000    103.000000    151.000000
# 50%     135.000000    72.000000   152.000000    105.000000    152.000000
# 75%     138.000000    73.000000   153.000000    108.000000    153.000000
# max     146.000000    83.000000   164.000000    114.000000    162.000000

# %% [markdown]
# ## Reading images

# %%
# function to read images based on index
def image_array(index, size=image_size_training, path=images_data_path):
    """
    This functions is for converting images to arrays to deal with it in the model.
    
    Input:  index of the image that we want to convert to array
            size of the image that we want for the array of the image
            path of the images data to get the image
            
    Output: the image array as numpy array
    """
    # to get the path based on index
    path = "{}/{}".format(str(path),str(df_org.iloc[index].image_id))
    
    # to read the image
    image = PIL.Image.open(path).resize(size)
    image_array = np.asarray(image)
    
    return image_array

# %%
# function to get a list of all key points of the face
def image_key_points_list(index, df = df_org):
    """
    This function for getting the key points on the face as list to deal with it in plotting sections
    """
    # box dictionary
    points_list = [df.iloc[index].lefteye_x,
                   df.iloc[index].lefteye_y,
                   df.iloc[index].righteye_x,
                   df.iloc[index].righteye_y,
                   df.iloc[index].nose_x,
                   df.iloc[index].nose_y,
                   df.iloc[index].leftmouth_x,
                   df.iloc[index].leftmouth_y,
                   df.iloc[index].rightmouth_x,
                   df.iloc[index].rightmouth_y]
    
    return points_list

# %%
# function to plot the image with green box around the faces
def plotting_image_with_box(index, df = df_org, size=original_image_size):
    """
    This function for plotting the image with points on facial features and box around the face
    """
    test_image = image_array(index, size)
    points_list = image_key_points_list(index, df)
    
    # face points
    le_x, le_y, re_x, re_y = points_list[0], points_list[1], points_list[2], points_list[3]
    n_x, n_y = points_list[4], points_list[5]
    lm_x, lm_y, rm_x, rm_y = points_list[6], points_list[7], points_list[8], points_list[9]
    
    # Create figure and axes
    fig, ax = plt.subplots()
    # plot the image
    ax.imshow(test_image)
    # plot the points on the face
    ax.plot([le_x,re_x,n_x,lm_x,rm_x], [le_y,re_y,n_y,lm_y,rm_y], 'bo-')
    
    # plot the box around the face
    width = abs(le_x-rm_x-60)
    height = abs(le_y-rm_y-75)
    rect = patches.Rectangle((le_x-30, le_y-40), width, height, linewidth=4, edgecolor='g', facecolor='none')
    ax.add_patch(rect);

# %%
#plotting the image with facial key points
plotting_image_with_box(25)

# %% [markdown]
# ## Preparing the data for our Deep Learning

# %% [markdown]
# ### Now, we will rescale the keypoints on the basis of rescaled images

# %%
# copy a version from the data to prepare it for analysis
df = df_org.copy()

# check
df.head(3)
# Out:
#      image_id  lefteye_x  lefteye_y  righteye_x  righteye_y  nose_x  nose_y  \
# 0  000001.jpg         69        109         106         113      77     142
# 1  000002.jpg         69        110         107         112      81     135
# 2  000003.jpg         76        112         104         106     108     128
#
#    leftmouth_x  leftmouth_y  rightmouth_x  rightmouth_y
# 0           73          152           108           154
# 1           70          151           108           153
# 2           74          156            98           158

# %%
# function for updating key points for a new size
def rescale_key_points(oldsize=original_image_size, newsize=image_size_training):
    """
    This function is for rescaling the key points from the original scale to a nwe scale from our chossen and we reduce
    the image size to make the analysis faster and using lower memory
    """
    # old and nwe sizes (x,y) values
    x_axis_old = oldsize[0]
    y_axis_old = oldsize[1]

    x_axis_new = newsize[0]
    y_axis_new = newsize[1]

    x_ratio = x_axis_new / x_axis_old
    y_ratio = y_axis_new / y_axis_old
    
    # converting the keypoints values to be trained with the new size of the images
    keypoints_x = ['lefteye_x', 'righteye_x', 'nose_x', 'leftmouth_x', 'rightmouth_x']
    keypoints_y = ['lefteye_y', 'righteye_y', 'nose_y', 'leftmouth_y', 'rightmouth_y']
    
    df[keypoints_x] = (df[keypoints_x] * x_ratio).astype('int')
    df[keypoints_y] = (df[keypoints_y] * y_ratio).astype('int')
    
    return 0

# call the function
rescale_key_points()

# check
df.head()
# Out:
#      image_id  lefteye_x  lefteye_y  righteye_x  righteye_y  nose_x  nose_y  \
# 0  000001.jpg         38         40          59          41      43      52
# 1  000002.jpg         38         40          60          41      45      50
# 2  000003.jpg         42         41          58          39      60      47
# 3  000004.jpg         40         41          60          40      56      51
# 4  000005.jpg         37         42          62          41      48      44
#
#    leftmouth_x  leftmouth_y  rightmouth_x  rightmouth_y
# 0           41           56            60            57
# 1           39           56            60            56
# 2           41           57            55            58
# 3           39           57            56            56
# 4           39           54            58            55

# %%
images=images_data
labels=df

# %%
from sklearn.model_selection import train_test_split

# %%
train_images,test_images,train_labels,test_labels=train_test_split(images,labels,
                                                                  test_size=0.3,random_state=42)

# %%
y_test=test_labels.drop(["image_id"],axis=1)
y_train=train_labels.drop(["image_id"],axis=1)

X_test=test_images
X_train=train_images

# %% [markdown]
# ## Further splitting the test data into validation and test data

# %%
X_test, X_val, y_test, y_val=train_test_split(X_test, y_test,
                                              test_size=0.5,random_state=42)

# %% [markdown]
# ## Building the CNN-based Deep Learning model

# %%
# diminsions of the image in the traing process
x_ = image_size_training[0]
y_ = image_size_training[1]

# build the model
model = Sequential()

model.add(Conv2D(filters=8, kernel_size=(3, 3), padding='same', activation="relu", input_shape=(y_,x_,3)))
model.add(Conv2D(filters=8, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation="relu"))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(10, activation='relu'))
# Out:
# C:\Users\dashd\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Having a quick view of the model architecture

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 81, 100, 8)     │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 81, 100, 8)     │           584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 40, 50, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 40, 50, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 40, 50, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 40, 50, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 20, 25, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 20, 25, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 20, 25, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 10, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 10, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 10, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 5, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 5, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1920)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │       122,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │           170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 153,154 (598.26 KB)
#  Trainable params: 153,154 (598.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="rmsprop", loss='mean_squared_error',metrics=["mae"])

# %%
# fitting the model with our data
training_process = model.fit(X_train, y_train, epochs=50, validation_data=(X_val, y_val), batch_size=4, shuffle=True)
# Out:
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 1304.4950 - mae: 30.5670 - val_loss: 396.7799 - val_mae: 17.4409
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 528.6345 - mae: 18.6579 - val_loss: 267.6355 - val_mae: 15.8458
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 345.4346 - mae: 14.8262 - val_loss: 415.5346 - val_mae: 19.9890
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 266.0124 - mae: 13.2778 - val_loss: 168.2282 - val_mae: 12.6367
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 203.6671 - mae: 11.3513 - val_loss: 207.1171 - val_mae: 14.0500
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 218.3223 - mae: 11.7008 - val_loss: 379.0058 - val_mae: 19.1397
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 182.7703 - mae: 10.9209 - val_loss: 321.7639 - val_mae: 17.6473
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 156.0466 - mae: 10.0048 - val_loss: 163.8119 - val_mae: 12.5237
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 168.3199 - mae: 10.3581 - val_loss: 9.1972 - val_mae: 2.6684
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 148.1216 - mae: 9.5931 - val_loss: 233.4160 - val_mae: 15.0166
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 152.9179 - mae: 9.7010 - val_loss: 67.4422 - val_mae: 7.9431
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 130.8512 - mae: 9.1351 - val_loss: 43.3907 - val_mae: 6.3170
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 125.8086 - mae: 8.8327 - val_loss: 17.1872 - val_mae: 3.8511
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 130.1818 - mae: 9.1500 - val_loss: 15.6823 - val_mae: 3.6665
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 120.4259 - mae: 8.5666 - val_loss: 137.0197 - val_mae: 11.4674
# Epoch 16/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 134.4046 - mae: 9.1048 - val_loss: 39.5912 - val_mae: 6.0319
# Epoch 17/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 134.5170 - mae: 9.2258 - val_loss: 41.3031 - val_mae: 6.1674
# Epoch 18/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 102.5682 - mae: 8.0375 - val_loss: 10.4913 - val_mae: 2.9080
# Epoch 19/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 107.5222 - mae: 8.0614 - val_loss: 27.5022 - val_mae: 4.9605
# Epoch 20/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 113.5199 - mae: 8.3472 - val_loss: 78.3242 - val_mae: 8.5992
# Epoch 21/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 119.1619 - mae: 8.7158 - val_loss: 15.8110 - val_mae: 3.6913
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 109.7645 - mae: 8.2011 - val_loss: 93.5278 - val_mae: 9.4145
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 93.0901 - mae: 7.6225 - val_loss: 69.5877 - val_mae: 8.0894
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 106.3407 - mae: 8.2389 - val_loss: 11.3604 - val_mae: 3.0396
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 100.6812 - mae: 8.0955 - val_loss: 23.5337 - val_mae: 4.5834
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 103.5229 - mae: 7.8852 - val_loss: 12.5616 - val_mae: 3.2356
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 111.7148 - mae: 8.3263 - val_loss: 27.1917 - val_mae: 4.9443
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 96.5995 - mae: 7.8326 - val_loss: 64.6719 - val_mae: 7.7926
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 103.7706 - mae: 7.9325 - val_loss: 18.2120 - val_mae: 3.9821
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 102.3820 - mae: 8.0557 - val_loss: 20.7133 - val_mae: 4.2715
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 92.7705 - mae: 7.6170 - val_loss: 12.3796 - val_mae: 3.2125
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 94.5058 - mae: 7.8433 - val_loss: 50.3960 - val_mae: 6.8422
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 98.2947 - mae: 7.7875 - val_loss: 13.9112 - val_mae: 3.4196
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 102.4482 - mae: 8.0545 - val_loss: 6.4504 - val_mae: 2.1685
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 100.8342 - mae: 8.0299 - val_loss: 30.2912 - val_mae: 5.2445
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 103.5811 - mae: 8.1177 - val_loss: 46.7272 - val_mae: 6.5771
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 104.0788 - mae: 8.2344 - val_loss: 51.4253 - val_mae: 6.9102
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 102.0770 - mae: 8.0564 - val_loss: 52.4734 - val_mae: 6.9867
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 89.4583 - mae: 7.5221 - val_loss: 56.5909 - val_mae: 7.2625
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 96.5541 - mae: 7.8345 - val_loss: 27.3888 - val_mae: 4.9588
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 100.8606 - mae: 7.8643 - val_loss: 38.3094 - val_mae: 5.9249
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 88.6282 - mae: 7.4880 - val_loss: 35.7764 - val_mae: 5.7124
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 97.7247 - mae: 7.7243 - val_loss: 74.7094 - val_mae: 8.3895
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 95.6431 - mae: 7.8959 - val_loss: 34.4209 - val_mae: 5.6003
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 85.6285 - mae: 7.3708 - val_loss: 37.2142 - val_mae: 5.8320
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 86.5592 - mae: 7.3576 - val_loss: 19.3456 - val_mae: 4.1060
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 95.3956 - mae: 7.7018 - val_loss: 52.3350 - val_mae: 6.9706
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 85.6722 - mae: 7.2088 - val_loss: 57.3360 - val_mae: 7.3106
# Epoch 49/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 87.8907 - mae: 7.4993 - val_loss: 17.9297 - val_mae: 3.9446
# Epoch 50/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 88.5568 - mae: 7.4026 - val_loss: 2.9731 - val_mae: 1.1951

# %% [markdown]
# ## Testing the model

# %% [markdown]
# ### Evaluating the model performance on the basis of

# %%
model.evaluate(X_test, y_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.9888 - mae: 1.2139
# [3.006157398223877, 1.2125343084335327]

# %%
def predictions_test_model(index):
    img = tf.keras.preprocessing.image.load_img("{}/0{}.jpg".format(images_data_path, index),target_size=(y_,x_,3))
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = img/255
    points_list = model.predict(img.reshape(1,y_,x_,3)).astype('int')[0]
    
    # converting key points values to the original size
    x_ratio = 1.05 * (original_image_size[0] / image_size_training[0])
    y_ratio = 1.085 * (original_image_size[1] / image_size_training[1])
    """
    In the previous ratios we multiply them by contant to reduce the noise that happened when we rescaled the points in
    the previous training, there is no meaning for these numbers (i just pick them with trails)
    """
    
    points_list[0] = int(points_list[0] * x_ratio)
    points_list[2] = int(points_list[2] * x_ratio)
    points_list[4] = int(points_list[4] * x_ratio)
    points_list[6] = int(points_list[6] * x_ratio)
    points_list[8] = int(points_list[8] * x_ratio)
    
    points_list[1] = int(points_list[1] * y_ratio)
    points_list[3] = int(points_list[3] * y_ratio)
    points_list[5] = int(points_list[5] * y_ratio)
    points_list[7] = int(points_list[7] * y_ratio)
    points_list[9] = int(points_list[9] * y_ratio)
    
    return points_list

# %%
# function to plot the image with green box around the faces
def test_image_with_box_plot(index, pred_or_actual = 'pred', pointsColor='bo-' ,boxcolor='g'):
    img = tf.keras.preprocessing.image.load_img("{}/0{}.jpg".format(images_data_path, index),target_size=(y_org,x_org,3))
    img = tf.keras.preprocessing.image.img_to_array(img)
    test_image = img/255
    
    # predictions of key points on the face
    if pred_or_actual == 'pred':
        points_list = predictions_test_model(index)        # this for predections of the model
    elif pred_or_actual == 'actual':
        points_list = image_key_points_list(index)   # this for the actual labels of the test data
    
    # face points
    le_x, le_y, re_x, re_y = points_list[0], points_list[1], points_list[2], points_list[3]
    n_x, n_y = points_list[4], points_list[5]
    lm_x, lm_y, rm_x, rm_y = points_list[6], points_list[7], points_list[8], points_list[9]

    # Create figure and axes
    fig, ax = plt.subplots()
    # plot the image
    ax.imshow(test_image)
    # plot the points on the face
    ax.plot([le_x,re_x,n_x,lm_x,rm_x], [le_y,re_y,n_y,lm_y,rm_y], pointsColor)
    
    # plot the box around the face
    width = abs(le_x-rm_x-60)
    height = abs(le_y-rm_y-75)
    rect = patches.Rectangle((le_x-30, le_y-40), width, height, linewidth=4, edgecolor=boxcolor, facecolor='none')
    ax.add_patch(rect);
    return points_list

# %%
# Using the model to predict a sample image which doesn't exist in train,test, or validation data
index = 34200
print('RED box for predections\n') 
print('GREEN box for actual labels\n')
test_image_with_box_plot(index, pred_or_actual = 'pred', pointsColor='mo-' ,boxcolor='r')
# Out:
# RED box for predections
#
# GREEN box for actual labels
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# array([ 71, 116, 110, 116,  89, 143,  71, 160, 108, 160])

# %%
# losses of both training and validation sets
loss = training_process.history['loss']
val_loss = training_process.history['val_loss']

# plot both losses
plt.plot(loss)
plt.plot(val_loss)
plt.legend(['loss', 'val_loss']);

# %% [markdown]
# ## Saving the model for future use

# %%
# # Load the model saved in .h5 format
# model = load_model('model.h5')

# Save the model in the new .keras format
model.save('model.keras')

# %% [markdown]
# Fine Tuning the Model

# %%
# import numpy as np
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras import layers
# import keras_tuner as kt
# from sklearn.utils import class_weight

# # ----------------------------------------------------------------
# # Step 1: Compute Class Weights for Imbalanced Data
# # Computing class weights helps the model give more importance to under-represented classes.
# # This is particularly useful for highly imbalanced datasets (e.g., fraud detection, rare disease classification).
# # ----------------------------------------------------------------
# # Computing class weights helps the model give more importance to under-represented classes.
# unique_classes = np.unique(y_train)
# weights = class_weight.compute_class_weight(class_weight='balanced', 
#                                             classes=unique_classes, 
#                                             y=y_train)
# class_weights = dict(zip(unique_classes, weights))
# print("Computed class weights:", class_weights)

# # ----------------------------------------------------------------
# # Step 2: Define the Model Builder Function for Keras Tuner
# # ----------------------------------------------------------------
# # This function allows the tuner to explore different architectures and training parameters.
# def build_model(hp):
#     model = keras.Sequential()
    
#     # Input layer based on the pre-determined input shape
#     model.add(layers.Input(shape=input_shape))
    
#     # -------------------------------
#     # Convolutional Layers:
#     # -------------------------------
#     # We tune the number of convolutional layers and their parameters (filters and kernel size)
#     for i in range(hp.Int('num_conv_layers', 1, 3, default=2)):
#         filters = hp.Int(f'filters_{i}', min_value=32, max_value=128, step=32, default=64)
#         kernel_size = hp.Choice(f'kernel_size_{i}', values=[3, 5], default=3)
#         model.add(layers.Conv2D(filters=filters, kernel_size=kernel_size, 
#                                 activation='relu', padding='same'))
#         model.add(layers.MaxPooling2D(pool_size=(2,2)))
    
#     # Flatten the output for Dense layers
#     model.add(layers.Flatten())
    
#     # -------------------------------
#     # Dense Layers:
#     # -------------------------------
#     # Similarly, we tune the number of dense layers, units in each, and dropout rates for regularization.
#     for i in range(hp.Int('num_dense_layers', 1, 3, default=2)):
#         units = hp.Int(f'units_{i}', min_value=32, max_value=256, step=32, default=128)
#         model.add(layers.Dense(units, activation='relu'))
#         dropout_rate = hp.Float(f'dropout_{i}', min_value=0.0, max_value=0.5, step=0.1, default=0.2)
#         if dropout_rate > 0:
#             model.add(layers.Dropout(dropout_rate))
    
#     # Output layer: Softmax activation for multi-class classification
#     model.add(layers.Dense(num_classes, activation='softmax'))
    
#     # Tune the learning rate for the Adam optimizer
#     learning_rate = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, 
#                              sampling='log', default=1e-3)
#     model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
#                   loss='sparse_categorical_crossentropy',
#                   metrics=['accuracy'])
#     return model

# # ----------------------------------------------------------------
# # Step 3: Set Up Keras Tuner with Early Stopping
# # ----------------------------------------------------------------
# ## EarlyStopping prevents the model from training for too long if it stops improving.
# # This helps avoid overfitting, where the model learns patterns specific to the training data but does not generalize well to new data.
# early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# # # Hyperband is an optimization technique that adaptively allocates resources to different configurations.
# # It quickly eliminates poor-performing models while spending more time refining promising ones.

# tuner = kt.Hyperband(build_model,
#                      objective='val_accuracy',
#                      max_epochs=20,
#                      factor=3,
#                      directory='docusync_tuning_dir',
#                      project_name='docusync_model')

# # ----------------------------------------------------------------
# # Step 4: Execute the Hyperparameter Search
# # ----------------------------------------------------------------
# # Pass class weights during training to address any data imbalance.
# tuner.search(x_train, y_train,
#              epochs=20,
#              validation_data=(x_val, y_val),
#              callbacks=[early_stop],
#              class_weight=class_weights)

# # Retrieve the best model from the tuning process.
# best_model = tuner.get_best_models(num_models=1)[0]
# print("Best model summary:")
# best_model.summary()

# # ----------------------------------------------------------------
# # Step 5: Evaluate the Best Model on the Test Set
# # ----------------------------------------------------------------
# test_loss, test_accuracy = best_model.evaluate(x_test, y_test)
# print("Test Accuracy:", test_accuracy)
